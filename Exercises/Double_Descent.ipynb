# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-sikzosft
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-sikzosft
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=1ab2532556ce128db8ae658cfbe48829fc872556656666acaf1efe6c615d1592
#   Stored in directory: /tmp/pip-ephem-wheel-cache-7gnwtu3n/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.267181, train error 86.85,  test loss 2.260168, test error 86.43
# Epoch   100, train loss 1.850832, train error 70.00,  test loss 1.696787, test error 68.70
# Epoch   200, train loss 1.846758, train error 70.47,  test loss 1.696997, test error 68.05
# Epoch   300, train loss 1.847545, train error 70.25,  test loss 1.701519, test error 67.82
# Epoch   400, train loss 1.845770, train error 70.15,  test loss 1.699884, test error 68.30
# Epoch   500, train loss 1.844976, train error 70.10,  test loss 1.701540, test error 68.28
# Epoch   600, train loss 1.844151, train error 70.35,  test loss 1.695182, test error 68.22
# Epoch   700, train loss 1.847577, train error 70.15,  test loss 1.699334, test error 67.85
# Epoch   800, train loss 1.846273, train error 69.75,  test loss 1.705036, test error 67.72
# Epoch   900, train loss 1.844293, train error 70.10,  test loss 1.700132, test error 67.72
# Training model with   4 hidden variables
# Epoch     0, train loss 2.280281, train error 83.45,  test loss 2.286732, test error 83.43
# Epoch   100, train loss 1.790244, train error 66.38,  test loss 1.620675, test error 64.97
# Epoch   200, train loss 1.773439, train error 65.45,  test loss 1.612529, test error 62.90
# Epoch   300, train loss 1.760870, train error 64.65,  test loss 1.595403, test error 61.30
# Epoch   400, train loss 1.743910, train error 63.38,  test loss 1.585948, test error 60.95
# Epoch   500, train loss 1.734740, train error 64.00,  test loss 1.583580, test error 61.05
# Epoch   600, train loss 1.726220, train error 63.53,  test loss 1.579476, test error 60.80
# Epoch   700, train loss 1.725047, train error 63.78,  test loss 1.576410, test error 61.70
# Epoch   800, train loss 1.724441, train error 64.03,  test loss 1.578772, test error 61.95
# Epoch   900, train loss 1.725731, train error 63.65,  test loss 1.575371, test error 60.88
# Training model with   6 hidden variables
# Epoch     0, train loss 2.232387, train error 83.47,  test loss 2.222460, test error 84.32
# Epoch   100, train loss 1.763756, train error 65.00,  test loss 1.632954, test error 63.62
# Epoch   200, train loss 1.725289, train error 63.80,  test loss 1.591608, test error 61.78
# Epoch   300, train loss 1.713837, train error 63.22,  test loss 1.585421, test error 62.17
# Epoch   400, train loss 1.713536, train error 62.70,  test loss 1.584968, test error 62.88
# Epoch   500, train loss 1.703916, train error 61.88,  test loss 1.577756, test error 61.80
# Epoch   600, train loss 1.701454, train error 63.03,  test loss 1.584758, test error 62.00
# Epoch   700, train loss 1.697566, train error 61.95,  test loss 1.584321, test error 61.47
# Epoch   800, train loss 1.697585, train error 62.28,  test loss 1.576416, test error 61.33
# Epoch   900, train loss 1.694143, train error 62.65,  test loss 1.581358, test error 61.67
# Training model with   8 hidden variables
# Epoch     0, train loss 2.252339, train error 81.85,  test loss 2.237094, test error 81.68
# Epoch   100, train loss 1.580641, train error 54.58,  test loss 1.408470, test error 53.65
# Epoch   200, train loss 1.523178, train error 53.15,  test loss 1.353325, test error 51.72
# Epoch   300, train loss 1.492649, train error 51.53,  test loss 1.337045, test error 50.25
# Epoch   400, train loss 1.477708, train error 50.92,  test loss 1.334952, test error 50.12
# Epoch   500, train loss 1.474598, train error 50.50,  test loss 1.348012, test error 50.95
# Epoch   600, train loss 1.465746, train error 51.30,  test loss 1.336524, test error 50.15
# Epoch   700, train loss 1.460713, train error 50.72,  test loss 1.339415, test error 50.60
# Epoch   800, train loss 1.460850, train error 50.00,  test loss 1.343609, test error 50.78
# Epoch   900, train loss 1.452023, train error 49.97,  test loss 1.350431, test error 50.70
# Training model with  10 hidden variables
# Epoch     0, train loss 2.272777, train error 86.60,  test loss 2.276480, test error 87.18
# Epoch   100, train loss 1.498158, train error 51.03,  test loss 1.360050, test error 52.12
# Epoch   200, train loss 1.442450, train error 48.85,  test loss 1.331998, test error 49.85
# Epoch   300, train loss 1.423104, train error 48.45,  test loss 1.346032, test error 51.38
# Epoch   400, train loss 1.416019, train error 48.62,  test loss 1.353704, test error 51.38
# Epoch   500, train loss 1.413264, train error 49.05,  test loss 1.360852, test error 51.55
# Epoch   600, train loss 1.410913, train error 48.20,  test loss 1.361497, test error 51.10
# Epoch   700, train loss 1.401944, train error 48.20,  test loss 1.353121, test error 50.83
# Epoch   800, train loss 1.416275, train error 49.20,  test loss 1.370976, test error 52.15
# Epoch   900, train loss 1.407841, train error 49.15,  test loss 1.365271, test error 51.33
# Training model with  14 hidden variables
# Epoch     0, train loss 2.286139, train error 86.15,  test loss 2.285906, test error 86.07
# Epoch   100, train loss 1.390316, train error 46.17,  test loss 1.264927, test error 47.42
# Epoch   200, train loss 1.326393, train error 44.50,  test loss 1.279471, test error 47.70
# Epoch   300, train loss 1.306497, train error 43.78,  test loss 1.317888, test error 48.35
# Epoch   400, train loss 1.270956, train error 42.80,  test loss 1.339754, test error 48.12
# Epoch   500, train loss 1.267749, train error 42.62,  test loss 1.360699, test error 48.80
# Epoch   600, train loss 1.252640, train error 41.72,  test loss 1.366762, test error 49.12
# Epoch   700, train loss 1.253740, train error 42.58,  test loss 1.404869, test error 49.58
# Epoch   800, train loss 1.240413, train error 41.72,  test loss 1.398362, test error 48.55
# Epoch   900, train loss 1.256729, train error 42.28,  test loss 1.423881, test error 49.85
# Training model with  18 hidden variables
# Epoch     0, train loss 2.219282, train error 83.12,  test loss 2.221873, test error 83.25
# Epoch   100, train loss 1.290405, train error 42.30,  test loss 1.211734, test error 44.65
# Epoch   200, train loss 1.208226, train error 39.90,  test loss 1.254466, test error 45.15
# Epoch   300, train loss 1.174947, train error 39.70,  test loss 1.302468, test error 45.75
# Epoch   400, train loss 1.155967, train error 39.35,  test loss 1.328406, test error 46.92
# Epoch   500, train loss 1.139364, train error 38.20,  test loss 1.332587, test error 46.58
# Epoch   600, train loss 1.132977, train error 38.60,  test loss 1.383577, test error 47.92
# Epoch   700, train loss 1.103409, train error 37.65,  test loss 1.400538, test error 47.55
# Epoch   800, train loss 1.092327, train error 36.70,  test loss 1.439631, test error 47.88
# Epoch   900, train loss 1.082370, train error 36.33,  test loss 1.453773, test error 47.60
# Training model with  22 hidden variables
# Epoch     0, train loss 2.168235, train error 80.07,  test loss 2.160833, test error 79.97
# Epoch   100, train loss 1.273171, train error 42.25,  test loss 1.285196, test error 47.83
# Epoch   200, train loss 1.151626, train error 38.72,  test loss 1.332218, test error 48.70
# Epoch   300, train loss 1.090522, train error 36.33,  test loss 1.402267, test error 49.90
# Epoch   400, train loss 1.042470, train error 35.57,  test loss 1.430822, test error 49.62
# Epoch   500, train loss 1.029618, train error 35.47,  test loss 1.518542, test error 50.45
# Epoch   600, train loss 1.001886, train error 35.07,  test loss 1.532282, test error 50.28
# Epoch   700, train loss 0.989818, train error 33.88,  test loss 1.591148, test error 50.85
# Epoch   800, train loss 0.987484, train error 34.12,  test loss 1.612893, test error 50.33
# Epoch   900, train loss 0.974175, train error 34.93,  test loss 1.672202, test error 51.83
# Training model with  26 hidden variables
# Epoch     0, train loss 2.115983, train error 79.28,  test loss 2.060574, test error 77.90
# Epoch   100, train loss 1.179518, train error 39.30,  test loss 1.322823, test error 47.92
# Epoch   200, train loss 1.046448, train error 35.00,  test loss 1.458584, test error 49.35
# Epoch   300, train loss 0.970593, train error 32.05,  test loss 1.526138, test error 50.70
# Epoch   400, train loss 0.933394, train error 31.05,  test loss 1.588251, test error 50.67
# Epoch   500, train loss 0.940337, train error 32.07,  test loss 1.713911, test error 51.90
# Epoch   600, train loss 0.871776, train error 29.97,  test loss 1.749705, test error 52.12
# Epoch   700, train loss 0.858490, train error 29.72,  test loss 1.864138, test error 53.00
# Epoch   800, train loss 0.849163, train error 29.03,  test loss 1.928585, test error 53.00
# Epoch   900, train loss 0.823619, train error 28.40,  test loss 1.968345, test error 52.72
# Training model with  30 hidden variables
# Epoch     0, train loss 2.160486, train error 81.03,  test loss 2.124110, test error 80.45
# Epoch   100, train loss 1.134244, train error 37.45,  test loss 1.368157, test error 49.22
# Epoch   200, train loss 0.953930, train error 31.95,  test loss 1.585806, test error 52.20
# Epoch   300, train loss 0.852486, train error 28.35,  test loss 1.804738, test error 53.28
# Epoch   400, train loss 0.780751, train error 26.30,  test loss 1.994933, test error 54.10
# Epoch   500, train loss 0.749832, train error 25.68,  test loss 2.192643, test error 55.30
# Epoch   600, train loss 0.735181, train error 24.65,  test loss 2.303748, test error 54.97
# Epoch   700, train loss 0.699964, train error 22.45,  test loss 2.383161, test error 54.45
# Epoch   800, train loss 0.687482, train error 21.85,  test loss 2.553160, test error 56.17
# Epoch   900, train loss 0.697813, train error 22.97,  test loss 2.646488, test error 56.20
# Training model with  35 hidden variables
# Epoch     0, train loss 2.098043, train error 78.70,  test loss 2.056601, test error 78.65
# Epoch   100, train loss 1.057424, train error 35.70,  test loss 1.440791, test error 51.62
# Epoch   200, train loss 0.835802, train error 28.50,  test loss 1.714660, test error 53.67
# Epoch   300, train loss 0.705296, train error 24.22,  test loss 2.030102, test error 54.70
# Epoch   400, train loss 0.633064, train error 21.97,  test loss 2.442647, test error 56.08
# Epoch   500, train loss 0.600870, train error 21.45,  test loss 2.832657, test error 56.97
# Epoch   600, train loss 0.533371, train error 18.18,  test loss 3.147689, test error 56.30
# Epoch   700, train loss 0.496576, train error 16.57,  test loss 3.491709, test error 57.38
# Epoch   800, train loss 0.509975, train error 17.97,  test loss 3.754453, test error 57.72
# Epoch   900, train loss 0.470447, train error 16.12,  test loss 4.027377, test error 57.25
# Training model with  40 hidden variables
# Epoch     0, train loss 2.079273, train error 76.70,  test loss 2.023622, test error 76.60
# Epoch   100, train loss 0.926469, train error 31.03,  test loss 1.468185, test error 51.12
# Epoch   200, train loss 0.663382, train error 22.30,  test loss 1.938792, test error 53.35
# Epoch   300, train loss 0.540055, train error 18.80,  test loss 2.527300, test error 54.40
# Epoch   400, train loss 0.418338, train error 14.10,  test loss 3.167381, test error 55.75
# Epoch   500, train loss 0.346710, train error 12.03,  test loss 3.942719, test error 56.30
# Epoch   600, train loss 0.294575, train error 10.10,  test loss 4.735627, test error 56.45
# Epoch   700, train loss 0.269811, train error 9.60,  test loss 5.410531, test error 56.92
# Epoch   800, train loss 0.301385, train error 10.75,  test loss 6.135424, test error 58.22
# Epoch   900, train loss 0.235356, train error 8.10,  test loss 6.689801, test error 57.67
# Training model with  45 hidden variables
# Epoch     0, train loss 2.120531, train error 78.20,  test loss 2.053874, test error 76.65
# Epoch   100, train loss 0.780301, train error 25.00,  test loss 1.564783, test error 51.03
# Epoch   200, train loss 0.461200, train error 15.07,  test loss 2.375171, test error 53.80
# Epoch   300, train loss 0.280932, train error 8.53,  test loss 3.486437, test error 55.35
# Epoch   400, train loss 0.184381, train error 5.43,  test loss 4.840113, test error 55.88
# Epoch   500, train loss 0.227531, train error 8.00,  test loss 6.179818, test error 56.95
# Epoch   600, train loss 0.024367, train error 0.00,  test loss 7.381654, test error 56.55
# Epoch   700, train loss 0.012202, train error 0.00,  test loss 8.342846, test error 56.75
# Epoch   800, train loss 0.008145, train error 0.00,  test loss 9.000025, test error 56.97
# Epoch   900, train loss 0.006157, train error 0.00,  test loss 9.502453, test error 56.92
# Training model with  50 hidden variables
# Epoch     0, train loss 2.099894, train error 77.07,  test loss 2.051056, test error 77.32
# Epoch   100, train loss 0.731400, train error 23.32,  test loss 1.531492, test error 48.90
# Epoch   200, train loss 0.344547, train error 10.12,  test loss 2.565960, test error 53.78
# Epoch   300, train loss 0.147210, train error 3.40,  test loss 4.025646, test error 54.42
# Epoch   400, train loss 0.032822, train error 0.05,  test loss 5.487960, test error 55.00
# Epoch   500, train loss 0.014750, train error 0.00,  test loss 6.488844, test error 55.15
# Epoch   600, train loss 0.009185, train error 0.00,  test loss 7.127544, test error 55.20
# Epoch   700, train loss 0.006566, train error 0.00,  test loss 7.605368, test error 55.15
# Epoch   800, train loss 0.004986, train error 0.00,  test loss 7.988950, test error 55.22
# Epoch   900, train loss 0.004022, train error 0.00,  test loss 8.311848, test error 55.35
# Training model with  55 hidden variables
# Epoch     0, train loss 2.083486, train error 77.30,  test loss 2.057039, test error 77.78
# Epoch   100, train loss 0.674521, train error 21.07,  test loss 1.595038, test error 50.58
# Epoch   200, train loss 0.246118, train error 6.00,  test loss 2.795607, test error 54.10
# Epoch   300, train loss 0.051929, train error 0.10,  test loss 4.393596, test error 54.15
# Epoch   400, train loss 0.017115, train error 0.00,  test loss 5.501123, test error 54.30
# Epoch   500, train loss 0.009528, train error 0.00,  test loss 6.166129, test error 54.62
# Epoch   600, train loss 0.006362, train error 0.00,  test loss 6.627102, test error 54.95
# Epoch   700, train loss 0.004727, train error 0.00,  test loss 6.982010, test error 55.00
# Epoch   800, train loss 0.003725, train error 0.00,  test loss 7.272264, test error 55.05
# Epoch   900, train loss 0.003027, train error 0.00,  test loss 7.514443, test error 54.97
# Training model with  60 hidden variables
# Epoch     0, train loss 2.129178, train error 77.95,  test loss 2.107306, test error 78.68
# Epoch   100, train loss 0.565427, train error 16.85,  test loss 1.746611, test error 51.88
# Epoch   200, train loss 0.125443, train error 1.95,  test loss 3.469553, test error 54.70
# Epoch   300, train loss 0.019809, train error 0.00,  test loss 4.929093, test error 54.88
# Epoch   400, train loss 0.009545, train error 0.00,  test loss 5.676058, test error 55.38
# Epoch   500, train loss 0.006014, train error 0.00,  test loss 6.164433, test error 55.50
# Epoch   600, train loss 0.004286, train error 0.00,  test loss 6.526722, test error 55.40
# Epoch   700, train loss 0.003286, train error 0.00,  test loss 6.810003, test error 55.45
# Epoch   800, train loss 0.002646, train error 0.00,  test loss 7.039829, test error 55.50
# Epoch   900, train loss 0.002203, train error 0.00,  test loss 7.243599, test error 55.58
# Training model with  70 hidden variables
# Epoch     0, train loss 2.040932, train error 76.50,  test loss 2.000196, test error 76.43
# Epoch   100, train loss 0.370592, train error 9.50,  test loss 2.018120, test error 52.40
# Epoch   200, train loss 0.034918, train error 0.03,  test loss 3.702958, test error 53.88
# Epoch   300, train loss 0.011071, train error 0.00,  test loss 4.502172, test error 53.60
# Epoch   400, train loss 0.006149, train error 0.00,  test loss 4.956557, test error 53.85
# Epoch   500, train loss 0.004133, train error 0.00,  test loss 5.269579, test error 53.80
# Epoch   600, train loss 0.003054, train error 0.00,  test loss 5.510211, test error 54.28
# Epoch   700, train loss 0.002393, train error 0.00,  test loss 5.696945, test error 54.17
# Epoch   800, train loss 0.001954, train error 0.00,  test loss 5.861604, test error 54.25
# Epoch   900, train loss 0.001641, train error 0.00,  test loss 6.000303, test error 54.17
# Training model with  80 hidden variables
# Epoch     0, train loss 2.016657, train error 74.32,  test loss 1.946794, test error 74.80
# Epoch   100, train loss 0.245361, train error 4.62,  test loss 2.136198, test error 51.92
# Epoch   200, train loss 0.020889, train error 0.00,  test loss 3.491851, test error 53.05
# Epoch   300, train loss 0.008253, train error 0.00,  test loss 4.082088, test error 53.15
# Epoch   400, train loss 0.004884, train error 0.00,  test loss 4.423015, test error 53.03
# Epoch   500, train loss 0.003360, train error 0.00,  test loss 4.671190, test error 53.12
# Epoch   600, train loss 0.002529, train error 0.00,  test loss 4.861096, test error 53.30
# Epoch   700, train loss 0.002005, train error 0.00,  test loss 5.015094, test error 53.22
# Epoch   800, train loss 0.001650, train error 0.00,  test loss 5.144070, test error 53.17
# Epoch   900, train loss 0.001395, train error 0.00,  test loss 5.258712, test error 53.28
# Training model with  90 hidden variables
# Epoch     0, train loss 1.997392, train error 73.00,  test loss 1.945063, test error 73.47
# Epoch   100, train loss 0.146487, train error 1.05,  test loss 2.120122, test error 50.15
# Epoch   200, train loss 0.014748, train error 0.00,  test loss 3.170789, test error 50.65
# Epoch   300, train loss 0.006445, train error 0.00,  test loss 3.604368, test error 50.67
# Epoch   400, train loss 0.003934, train error 0.00,  test loss 3.868788, test error 50.62
# Epoch   500, train loss 0.002756, train error 0.00,  test loss 4.058195, test error 50.60
# Epoch   600, train loss 0.002097, train error 0.00,  test loss 4.204248, test error 50.55
# Epoch   700, train loss 0.001674, train error 0.00,  test loss 4.326521, test error 50.72
# Epoch   800, train loss 0.001386, train error 0.00,  test loss 4.427732, test error 50.65
# Epoch   900, train loss 0.001176, train error 0.00,  test loss 4.516164, test error 50.53
# Training model with 100 hidden variables
# Epoch     0, train loss 1.966010, train error 72.12,  test loss 1.909294, test error 73.97
# Epoch   100, train loss 0.085676, train error 0.10,  test loss 2.264528, test error 50.20
# Epoch   200, train loss 0.011791, train error 0.00,  test loss 3.140929, test error 51.22
# Epoch   300, train loss 0.005535, train error 0.00,  test loss 3.500119, test error 51.17
# Epoch   400, train loss 0.003439, train error 0.00,  test loss 3.731907, test error 50.97
# Epoch   500, train loss 0.002452, train error 0.00,  test loss 3.900754, test error 51.08
# Epoch   600, train loss 0.001881, train error 0.00,  test loss 4.033595, test error 51.08
# Epoch   700, train loss 0.001513, train error 0.00,  test loss 4.142926, test error 51.15
# Epoch   800, train loss 0.001258, train error 0.00,  test loss 4.236758, test error 51.17
# Epoch   900, train loss 0.001071, train error 0.00,  test loss 4.316652, test error 51.20
# Training model with 120 hidden variables
# Epoch     0, train loss 1.984734, train error 74.15,  test loss 1.906368, test error 74.07
# Epoch   100, train loss 0.051107, train error 0.00,  test loss 2.258785, test error 50.95
# Epoch   200, train loss 0.009542, train error 0.00,  test loss 2.879661, test error 50.67
# Epoch   300, train loss 0.004736, train error 0.00,  test loss 3.163385, test error 51.17
# Epoch   400, train loss 0.003034, train error 0.00,  test loss 3.345213, test error 51.17
# Epoch   500, train loss 0.002189, train error 0.00,  test loss 3.479946, test error 51.12
# Epoch   600, train loss 0.001692, train error 0.00,  test loss 3.587545, test error 51.08
# Epoch   700, train loss 0.001369, train error 0.00,  test loss 3.676377, test error 51.17
# Epoch   800, train loss 0.001144, train error 0.00,  test loss 3.752579, test error 51.03
# Epoch   900, train loss 0.000977, train error 0.00,  test loss 3.818132, test error 51.05
# Training model with 140 hidden variables
# Epoch     0, train loss 1.955835, train error 71.80,  test loss 1.891527, test error 73.25
# Epoch   100, train loss 0.036858, train error 0.00,  test loss 2.140209, test error 49.80
# Epoch   200, train loss 0.008088, train error 0.00,  test loss 2.617883, test error 50.15
# Epoch   300, train loss 0.004144, train error 0.00,  test loss 2.838178, test error 49.92
# Epoch   400, train loss 0.002692, train error 0.00,  test loss 2.987458, test error 49.92
# Epoch   500, train loss 0.001957, train error 0.00,  test loss 3.098092, test error 49.85
# Epoch   600, train loss 0.001522, train error 0.00,  test loss 3.184905, test error 49.72
# Epoch   700, train loss 0.001236, train error 0.00,  test loss 3.258696, test error 49.95
# Epoch   800, train loss 0.001035, train error 0.00,  test loss 3.321562, test error 49.88
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.375378, test error 49.83
# Training model with 160 hidden variables
# Epoch     0, train loss 1.949381, train error 73.38,  test loss 1.872045, test error 74.45
# Epoch   100, train loss 0.028366, train error 0.00,  test loss 2.147458, test error 48.33
# Epoch   200, train loss 0.007094, train error 0.00,  test loss 2.560833, test error 48.45
# Epoch   300, train loss 0.003719, train error 0.00,  test loss 2.766746, test error 48.72
# Epoch   400, train loss 0.002444, train error 0.00,  test loss 2.902738, test error 48.75
# Epoch   500, train loss 0.001789, train error 0.00,  test loss 3.002094, test error 48.78
# Epoch   600, train loss 0.001396, train error 0.00,  test loss 3.083718, test error 48.92
# Epoch   700, train loss 0.001137, train error 0.00,  test loss 3.150188, test error 49.03
# Epoch   800, train loss 0.000955, train error 0.00,  test loss 3.207033, test error 48.97
# Epoch   900, train loss 0.000819, train error 0.00,  test loss 3.256710, test error 48.95
# Training model with 180 hidden variables
# Epoch     0, train loss 1.936081, train error 71.80,  test loss 1.863587, test error 73.25
# Epoch   100, train loss 0.024487, train error 0.00,  test loss 2.089700, test error 49.03
# Epoch   200, train loss 0.006590, train error 0.00,  test loss 2.448577, test error 48.55
# Epoch   300, train loss 0.003531, train error 0.00,  test loss 2.630843, test error 48.45
# Epoch   400, train loss 0.002337, train error 0.00,  test loss 2.752248, test error 48.53
# Epoch   500, train loss 0.001720, train error 0.00,  test loss 2.844031, test error 48.62
# Epoch   600, train loss 0.001347, train error 0.00,  test loss 2.917433, test error 48.55
# Epoch   700, train loss 0.001100, train error 0.00,  test loss 2.977978, test error 48.40
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 3.030945, test error 48.42
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 3.075608, test error 48.45
# Training model with 200 hidden variables
# Epoch     0, train loss 1.914807, train error 69.68,  test loss 1.832870, test error 70.97
# Epoch   100, train loss 0.020987, train error 0.00,  test loss 1.948475, test error 46.78
# Epoch   200, train loss 0.006058, train error 0.00,  test loss 2.244339, test error 46.97
# Epoch   300, train loss 0.003301, train error 0.00,  test loss 2.398700, test error 46.97
# Epoch   400, train loss 0.002204, train error 0.00,  test loss 2.501086, test error 46.97
# Epoch   500, train loss 0.001630, train error 0.00,  test loss 2.579093, test error 47.00
# Epoch   600, train loss 0.001280, train error 0.00,  test loss 2.641875, test error 46.95
# Epoch   700, train loss 0.001048, train error 0.00,  test loss 2.693974, test error 46.95
# Epoch   800, train loss 0.000882, train error 0.00,  test loss 2.738460, test error 47.03
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.777718, test error 47.00
# Training model with 250 hidden variables
# Epoch     0, train loss 1.886405, train error 69.18,  test loss 1.828216, test error 70.95
# Epoch   100, train loss 0.016879, train error 0.00,  test loss 1.975343, test error 47.60
# Epoch   200, train loss 0.005312, train error 0.00,  test loss 2.237213, test error 47.40
# Epoch   300, train loss 0.002960, train error 0.00,  test loss 2.379044, test error 47.62
# Epoch   400, train loss 0.001999, train error 0.00,  test loss 2.474631, test error 47.72
# Epoch   500, train loss 0.001488, train error 0.00,  test loss 2.547603, test error 47.67
# Epoch   600, train loss 0.001174, train error 0.00,  test loss 2.606066, test error 47.65
# Epoch   700, train loss 0.000964, train error 0.00,  test loss 2.655626, test error 47.65
# Epoch   800, train loss 0.000814, train error 0.00,  test loss 2.697644, test error 47.62
# Epoch   900, train loss 0.000702, train error 0.00,  test loss 2.734863, test error 47.62
# Training model with 300 hidden variables
# Epoch     0, train loss 1.881773, train error 67.43,  test loss 1.814585, test error 70.25
# Epoch   100, train loss 0.014485, train error 0.00,  test loss 1.828826, test error 46.38
# Epoch   200, train loss 0.004848, train error 0.00,  test loss 2.034894, test error 46.30
# Epoch   300, train loss 0.002749, train error 0.00,  test loss 2.150827, test error 46.33
# Epoch   400, train loss 0.001873, train error 0.00,  test loss 2.229398, test error 46.33
# Epoch   500, train loss 0.001402, train error 0.00,  test loss 2.289291, test error 46.33
# Epoch   600, train loss 0.001111, train error 0.00,  test loss 2.337511, test error 46.25
# Epoch   700, train loss 0.000915, train error 0.00,  test loss 2.377513, test error 46.33
# Epoch   800, train loss 0.000774, train error 0.00,  test loss 2.412659, test error 46.33
# Epoch   900, train loss 0.000669, train error 0.00,  test loss 2.443246, test error 46.33
# Training model with 400 hidden variables
# Epoch     0, train loss 1.850634, train error 66.97,  test loss 1.774372, test error 69.68
# Epoch   100, train loss 0.011793, train error 0.00,  test loss 1.741281, test error 46.08
# Epoch   200, train loss 0.004210, train error 0.00,  test loss 1.915391, test error 46.03
# Epoch   300, train loss 0.002436, train error 0.00,  test loss 2.011128, test error 45.90
# Epoch   400, train loss 0.001677, train error 0.00,  test loss 2.077827, test error 45.88
# Epoch   500, train loss 0.001263, train error 0.00,  test loss 2.129174, test error 45.80
# Epoch   600, train loss 0.001006, train error 0.00,  test loss 2.170658, test error 45.78
# Epoch   700, train loss 0.000831, train error 0.00,  test loss 2.205882, test error 45.80
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.235954, test error 45.72
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.262362, test error 45.65

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
